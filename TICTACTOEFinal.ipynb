# %%
A = [[0, 0, 0], 
    [0, 0, 0],
    [0, 0, 0]]
x=0
y=0

print(A[0])
print(A[1])
print(A[2])
print("GAME START!")
for x in range(9):

    x, y = [int(x) for x in input("Enter two value for row and column. 0-2: ").split()] 
  
    if A[x][y] == 2:
        print("No cheating")
        continue
      
    A[x][y] = 1
    print(A[0])
    print(A[1])
    print(A[2])
    if A[0]==[1, 1, 1]:
        print("Player one win")
        break

    if A[1]==[1, 1, 1]:
        print("Player one win")
        break

    if A[2]==[1, 1, 1]:
        print("Player one win")
        break

    if A[0][0]== 1:
        if A[1][0]== 1:
            if A[2][0]== 1 :
                print("Player one wins")
                break
    if A[0][1]== 1:
        if A[1][1]== 1:
            if A[2][1]== 1:
                print("Player one wins")
                break
    if A[0][2]== 1:
        if A[1][2]== 1:
            if A[2][2]== 1:
                print("Player one wins")
                break
    if A[0][0]== 1:
        if A[1][1]== 1:
            if A[2][2]== 1:
                print("Player one wins")
                break
    if A[0][2]== 1 :
        if A[1][1]== 1:
            if A[2][0]== 1:
                print("Player one wins")
                break
    if A[0][0]!= 0:
        if A[1][0]!= 0:
            if A[2][0]!= 0 :
                if A[0][1]!= 0:
                    if A[1][1]!= 0:
                        if A[2][1]!= 0 :
                            if A[0][2]!= 0:
                                if A[1][2]!= 0:
                                    if A[2][2]!= 0 :
                                        print("No Winner")
                                        break

    print("pass to the next player")
    
    x, y = [int(x) for x in input("Enter two value for row and column. 0-2: ").split()] 
    if A[x][y] == 1:
        print("No cheating")
        continue
    A[x][y] = 2
    print(A[0])
    print(A[1])
    print(A[2]) 
    if A[0]==[2, 2, 2]:
        print("Player two win")
        break

    if A[1]==[2, 2, 2]:
        print("Player two win")
        break

    if A[2]==[2, 2, 2]:
        print("Player two win")
        break

    if A[0][0]== 2 :
        if A[1][0]== 2:
            if A[2][0]== 2:
                print("Player two wins")
                break
    if A[0][1]== 2:
        if A[1][1]== 2:
            if A[2][1]== 2:
                print("Player two wins")
                break
    if A[0][2]== 2:
        if A[1][2]== 2:
            if A[2][2]== 2:
                print("Player two wins")
                break
    if A[0][0]== 2:
        if A[1][1]== 2:
            if A[2][2]== 2:
                print("Player two wins")
                break
    if A[0][2]== 2:
        if A[1][1]== 2:
            if A[2][0]== 2:
                print("Player two wins")
                break
    if A[0][0]!= 0:
        if A[1][0]!= 0:
            if A[2][0]!= 0 :
                if A[0][1]!= 0:
                    if A[1][1]!= 0:
                        if A[2][1]!= 0 :
                            if A[0][2]!= 0:
                                if A[1][2]!= 0:
                                    if A[2][2]!= 0 :
                                        print("No Winner")
                                        break
            
    print("pass to the next player")
# Out:
# [0, 0, 0]
# [0, 0, 0]
# [0, 0, 0]
# GAME START!

# %%
# Out:
# [[1, 0, 1], [1, 0, 0], [1, 0, 0]]
# 1
# Player one wins
